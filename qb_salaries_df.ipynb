# %%
##   QUARTERBACK SALARIES
##   STILL MISSING ABOUT 10

# %%
import pandas as pd
import csv

# %%
######## READING IN YEARLY SALARIES OF 100 QUARTERBACKS

qb_salaries = "../mica_resources/population_salaries_by_season.csv"
qb_salaries_df = pd.read_csv(qb_salaries)

# %%
qb_salaries_df.head()
# Out:
#   career_Y  Tom Brady  Drew Brees  Ben Roethlisberger  Philip Rivers  \
# 0       Y1   205833.0    627500.0           1502000.0      2580000.0
# 1       Y2   310833.0    707500.0           4220250.0      4855000.0
# 2       Y3  1087834.0   2287500.0           4545750.0      5165000.0
# 3       Y4  3318750.0   2367500.0           3127000.0     10775000.0
# 4       Y5  5058750.0   8078000.0           7970000.0      7625000.0
#
#    Eli Manning   Matt Ryan  Aaron Rodgers  Mathew Stafford  Carson Palmer  \
# 0    2244000.0   6600000.0      1150000.0        3100000.0      2500000.0
# 1    4527926.0   9900000.0      1402500.0       12980000.0      5477242.0
# 2    7388074.0  12250000.0      1557500.0        6123750.0      8982758.0
# 3   10046666.0  13250000.0     13952500.0        8935000.0     12980000.0
# 4   12916666.0  13500000.0      9652500.0       17820000.0     13480000.0
#
#    ...  Sean Mannion  Tom Savage  Marques Tuiasosopo  Pat White  Bryce Petty  \
# ...
