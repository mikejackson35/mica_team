# %%
#   qb population of 100
#   this df contains our single-instance variables (as opposed to yearly)

# %%
import pandas as pd
import csv

# %%
#read in all quarterbacks drafted from 2000 - 2020

qb_population = "drafts_qb_only_all_years.csv"
qb_population_df = pd.read_csv(qb_population)
qb_population_df
# Out:
#                 Player  Year  Rnd  Pick  DrAge   Tm    G   GS  \
# 0            Tom Brady  2000    6   199     23  NWE  318  316
# 1           Drew Brees  2001    2    32     22  SDG  287  286
# 2   Ben Roethlisberger  2004    1    11     22  PIT  249  247
# 3        Philip Rivers  2004    1     4     22  NYG  244  240
# 4          Eli Manning  2004    1     1     23  SDG  236  234
# ..                 ...   ...  ...   ...    ...  ...  ...  ...
# 95         Bryce Petty  2015    4   103     24  NYJ   10    7
# 96        Ryan Lindley  2012    6   185     23  ARI   10    6
# 97        Spergon Wynn  2000    6   183     22  CLE   10    3
# 98           John Beck  2007    2    40     26  MIA    9    7
# 99         Drew Henson  2003    6   192     23  HOU    9    1
#
#           College/Univ
# 0             Michigan
# 1               Purdue
# 2           Miami (OH)
# 3   North Carolina St.
# 4          Mississippi
# ..                 ...
# 95              Baylor
# 96       San Diego St.
# ...
